# %% [markdown]
# <a href="https://colab.research.google.com/github/kNIG132103/Beginning-Cpp-Game-Programming/blob/master/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# !pip install pygit2==1.15.1

# Clone Fooocus if not already cloned
if not os.path.exists('/content/Fooocus'):
  # %cd /content
  # !git clone https://github.com/lllyasviel/Fooocus.git

# %cd /content/Fooocus

# Uninstall existing torch and torchvision to ensure a clean installation
# !pip uninstall -y torch torchvision torchaudio

# Install torch with CUDA 12.1 support
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# Run Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 63.9 MB/s eta 0:00:00
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6735, done.
# remote: Total 6735 (delta 0), reused 0 (delta 0), pack-reused 6735 (from 1)
# Receiving objects: 100% (6735/6735), 33.35 MiB | 52.62 MiB/s, done.
# Resolving deltas: 100% (3850/3850), done.
# /content/Fooocus
# Found existing installation: torch 2.9.0+cpu
# Uninstalling torch-2.9.0+cpu:
#   Successfully uninstalled torch-2.9.0+cpu
# Found existing installation: torchvision 0.24.0+cpu
# Uninstalling torchvision-0.24.0+cpu:
#   Successfully uninstalled torchvision-0.24.0+cpu
# Found existing installation: torchaudio 2.9.0+cpu
# Uninstalling torchaudio-2.9.0+cpu:
#   Successfully uninstalled torchaudio-2.9.0+cpu
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 MB 683.3 kB/s eta 0:00:00
# ...

# %%
import os

# !pip install pygit2==1.15.1

# Clone Fooocus if not already cloned
if not os.path.exists('/content/Fooocus'):
  # %cd /content
  # !git clone https://github.com/lllyasviel/Fooocus.git

# %cd /content/Fooocus

# Uninstall existing torch and torchvision to ensure a clean installation
# !pip uninstall -y torch torchvision torchaudio

# Install torch with CUDA 12.1 support
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# Reinstall numpy to the required version for Fooocus and CuPy compatibility
# !pip install numpy==1.26.4

# %%
# Run Fooocus again after reinstalling numpy and cupy
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram

# %%
import os

# !pip install pygit2==1.15.1

# Clone Fooocus if not already cloned
if not os.path.exists('/content/Fooocus'):
  # %cd /content
  # !git clone https://github.com/lllyasviel/Fooocus.git

# %cd /content/Fooocus

# Uninstall existing torch and torchvision to ensure a clean installation
# !pip uninstall -y torch torchvision torchaudio

# Install torch with CUDA 12.1 support
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# Reinstall numpy to the required version for Fooocus and CuPy compatibility
# !pip install numpy==1.26.4

# %%
# Explicitly uninstall any existing CuPy and then install cupy-cuda121
# !pip uninstall -y cupy cupy-cuda12x cupy-cuda11x cupy-cuda10x
# !pip install cupy-cuda121

# %%
# Run Fooocus again after reinstalling numpy and cupy
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
