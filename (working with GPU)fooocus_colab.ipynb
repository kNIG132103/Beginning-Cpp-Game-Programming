# %%
# 1. Force install PyTorch with CUDA (GPU) support
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# 2. Fix the CuPy/NumPy mismatch
# !pip uninstall -y cupy-cuda11x cupy-cuda12x
# !pip install cupy-cuda12x==13.1.0 --wheel
# !pip install "numpy<2.0" pygit2==1.15.1

# 3. Clone the repository (the "|| true" ignores the error if it's already downloaded)
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git || true
# %cd /content/Fooocus

# 4. Launch Fooocus using the GPU
# !python entry_with_update.py --share --always-high-vram
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
# WARNING: Skipping cupy-cuda11x as it is not installed.
# WARNING: Skipping cupy-cuda12x as it is not installed.
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --wheel
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 14913 MB, total RAM 12976 MB
# ...

# %% [markdown]
# **Download model and store in Google DRIVE**

# %%
# 1. Connect your Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Create a folder in your Drive to keep things organized
import os
os.makedirs('/content/drive/MyDrive/Fooocus_Models', exist_ok=True)
# %cd /content/drive/MyDrive/Fooocus_Models

# 3. Download the model to that folder
# (REPLACE 'YOUR_API_KEY_HERE' with your actual Civitai token if needed)
# !wget -O "custom_model.safetensors" "https://civitai.com/api/download/models/501240?type=Model&format=SafeTensor&size=full&fp=fp16&token=YOUR_API_KEY_HERE"

# 4. Check the file size to verify the download
print("\n--- DOWNLOAD CHECK ---")
# !ls -lh custom_model.safetensors
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Fooocus_Models
# --2026-04-13 04:13:54--  https://civitai.com/api/download/models/501240?type=Model&format=SafeTensor&size=full&fp=fp16&token=YOUR_API_KEY_HERE
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# ...

# %%
# Copy the model from your Drive to Fooocus
# !cp /content/drive/MyDrive/Fooocus_Models/custom_model.safetensors /content/Fooocus/models/checkpoints/

# Then launch Fooocus
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# cp: cannot create regular file '/content/Fooocus/models/checkpoints/': No such file or directory
# [Errno 2] No such file or directory: '/content/Fooocus'
# /content/drive/MyDrive/Fooocus_Models
# python3: can't open file '/content/drive/MyDrive/Fooocus_Models/entry_with_update.py': [Errno 2] No such file or directory
