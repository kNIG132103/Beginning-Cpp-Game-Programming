# %%
# 1. Force install PyTorch with CUDA (GPU) support
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# 2. Fix the CuPy/NumPy mismatch
# !pip uninstall -y cupy-cuda11x cupy-cuda12x
# !pip install cupy-cuda12x==13.1.0 --wheel
# !pip install "numpy<2.0" pygit2==1.15.1

# 3. Clone the repository (the "|| true" ignores the error if it's already downloaded)
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git || true
# %cd /content/Fooocus

# 4. Launch Fooocus using the GPU
# !python entry_with_update.py --share --always-high-vram
# Out:
# WARNING: Ignoring invalid distribution ~imm (/usr/local/lib/python3.12/dist-packages)
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
# WARNING: Ignoring invalid distribution ~imm (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~imm (/usr/local/lib/python3.12/dist-packages)
# WARNING: Skipping cupy-cuda11x as it is not installed.
# WARNING: Ignoring invalid distribution ~imm (/usr/local/lib/python3.12/dist-packages)
# WARNING: Skipping cupy-cuda12x as it is not installed.
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --wheel
# WARNING: Ignoring invalid distribution ~imm (/usr/local/lib/python3.12/dist-packages)
# ...

# %%
# 1. Fix the CuPy/NumPy mismatch for Colab's current environment
# !pip uninstall -y cupy-cuda11x cupy-cuda12x
# !pip install cupy-cuda12x==13.1.0 --wheel
# !pip install "numpy<2.0" pygit2==1.15.1

# 2. Clone the repository
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# 3. Launch Fooocus using the GPU
# !python entry_with_update.py --share --always-high-vram
# Out:
# WARNING: Skipping cupy-cuda11x as it is not installed.
# WARNING: Skipping cupy-cuda12x as it is not installed.
# WARNING: Skipping cupy as it is not installed.
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-cpu', '--attention-split', '--disable-image-log']
# Python 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Running on 1 CPU threads
# Total VRAM 12976 MB, total RAM 12976 MB
# Set vram state to: DISABLED
# Always offload VRAM
# Device: cpu
# VAE dtype: torch.float32
# Using split optimization for cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# ...
